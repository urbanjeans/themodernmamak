# %% [markdown]
# #The Modern Mamak: Data Filtering by Company Status
#
# The dataset will be separated into several dataframes: live stores (currently in operation) and non-live stores (currently not in operation) that were registered within each decade. This is to have a rough guage of how many stores of have closed down since the passing of each decade. This data would also be used to approximate the termination date of some non-live shops and for visualising the survivability of shops in each decade.
#
# <br>
#
# ###Content:
#
# 1. Separating Shops in the 1980s into Live and Non-live
# 2. Separating Shops in the 1990s into Live and Non-live
# 3. Separating Shops in the 2000s into Live and Non-live
# 4. Separating Shops in the 2010s into Live and Non-live
# 5. Separating Shops in the 2020s into Live and Non-live

# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Google credentials
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Read Files

# %%
base_path = "/content/drive/MyDrive/Mamak Stores/ACRA data/"

decades = ["1980s", "1990s", "2000s", "2010s", "2020s"]

mamaks_geo = {decade: pd.read_csv(f"{base_path}mamaks_{decade}_geo.csv") for decade in decades}

mm_1980s_geo = mamaks_geo["1980s"]
mm_1990s_geo = mamaks_geo["1990s"]
mm_2000s_geo = mamaks_geo["2000s"]
mm_2010s_geo = mamaks_geo["2010s"]
mm_2020s_geo = mamaks_geo["2020s"]

# %% [markdown]
# #Definitions for Separating Live and non-Live Shops

# %%
def get_live_shops(df):
  temp_df_live = df[
    (df['entity_status_description'] == 'Live') |
    (df['entity_status_description'] == 'Live Company')
  ]
  temp_df_live = temp_df_live.reset_index(drop=True)

  return temp_df_live

# %%
def get_nlive_shops(df):
  temp_df_nlive = df[
    (df['entity_status_description'] != 'Live') &
    (df['entity_status_description'] != 'Live Company')
  ]
  temp_df_nlive = temp_df_nlive.reset_index(drop=True)

  return temp_df_nlive

# %% [markdown]
# #Separating Shops into Live and Non-live

# %% [markdown]
# ###1980s

# %%
mm_1980s_live = get_live_shops(mm_1980s_geo)
mm_1980s_nlive = get_nlive_shops(mm_1980s_geo)

# %%
mm_1980s_live.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                47 non-null     object
#  1   issuance_agency_id                 47 non-null     object
#  2   entity_name                        47 non-null     object
#  3   entity_type_description            47 non-null     object
#  4   business_constitution_description  47 non-null     object
#  5   company_type_description           47 non-null     object
#  6   paf_constitution_description       47 non-null     object
#  7   entity_status_description          47 non-null     object
#  8   registration_incorporation_date    47 non-null     object
#  9   uen_issue_date                     47 non-null     object
#  10  address_type                       47 non-null     object
#  11  block                              47 non-null     object
#  12  street_name                        47 non-null     object
#  13  level_no                           47 non-null     object
#  14  unit_no                            47 non-null     object
#  15  building_name                      47 non-null     object
#  16  postal_code                        47 non-null     object
#  17  other_address_line1                47 non-null     object
#  18  other_address_line2                47 non-null     object
#  19  account_due_date                   47 non-null     object
#  20  annual_return_date                 47 non-null     object
#  21  primary_ssic_code                  47 non-null     int64
#  22  primary_ssic_description           47 non-null     object
#  23  primary_user_described_activity    47 non-null     object
#  24  secondary_ssic_code                0 non-null      float64
#  25  secondary_ssic_description         47 non-null     object
#  26  secondary_user_described_activity  47 non-null     object
#  27  registration_year                  47 non-null     int64
#  28  Address                            47 non-null     object
#  29  Add_lat                            47 non-null     float64
#  30  Add_lon                            47 non-null     float64
# dtypes: float64(3), int64(2), object(26)
# memory usage: 11.5+ KB

# %%
mm_1980s_nlive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                893 non-null    object
#  1   issuance_agency_id                 893 non-null    object
#  2   entity_name                        893 non-null    object
#  3   entity_type_description            893 non-null    object
#  4   business_constitution_description  893 non-null    object
#  5   company_type_description           893 non-null    object
#  6   paf_constitution_description       893 non-null    object
#  7   entity_status_description          893 non-null    object
#  8   registration_incorporation_date    893 non-null    object
#  9   uen_issue_date                     893 non-null    object
#  10  address_type                       893 non-null    object
#  11  block                              893 non-null    object
#  12  street_name                        893 non-null    object
#  13  level_no                           893 non-null    object
#  14  unit_no                            893 non-null    object
#  15  building_name                      893 non-null    object
#  16  postal_code                        893 non-null    object
#  17  other_address_line1                893 non-null    object
#  18  other_address_line2                893 non-null    object
#  19  account_due_date                   893 non-null    object
#  20  annual_return_date                 893 non-null    object
#  21  primary_ssic_code                  893 non-null    int64
#  22  primary_ssic_description           893 non-null    object
#  23  primary_user_described_activity    893 non-null    object
#  24  secondary_ssic_code                0 non-null      float64
#  25  secondary_ssic_description         893 non-null    object
#  26  secondary_user_described_activity  893 non-null    object
#  27  registration_year                  893 non-null    int64
#  28  Address                            893 non-null    object
#  29  Add_lat                            893 non-null    float64
#  30  Add_lon                            893 non-null    float64
# dtypes: float64(3), int64(2), object(26)
# memory usage: 216.4+ KB

# %% [markdown]
# ###1990s

# %%
mm_1990s_live = get_live_shops(mm_1990s_geo)
mm_1990s_nlive = get_nlive_shops(mm_1990s_geo)

# %%
mm_1990s_live.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                76 non-null     object
#  1   issuance_agency_id                 76 non-null     object
#  2   entity_name                        76 non-null     object
#  3   entity_type_description            76 non-null     object
#  4   business_constitution_description  76 non-null     object
#  5   company_type_description           76 non-null     object
#  6   paf_constitution_description       76 non-null     object
#  7   entity_status_description          76 non-null     object
#  8   registration_incorporation_date    76 non-null     object
#  9   uen_issue_date                     76 non-null     object
#  10  address_type                       76 non-null     object
#  11  block                              76 non-null     object
#  12  street_name                        76 non-null     object
#  13  level_no                           76 non-null     object
#  14  unit_no                            76 non-null     object
#  15  building_name                      76 non-null     object
#  16  postal_code                        76 non-null     object
#  17  other_address_line1                76 non-null     object
#  18  other_address_line2                76 non-null     object
#  19  account_due_date                   76 non-null     object
#  20  annual_return_date                 76 non-null     object
#  21  primary_ssic_code                  76 non-null     int64
#  22  primary_ssic_description           76 non-null     object
#  23  primary_user_described_activity    76 non-null     object
#  24  secondary_ssic_code                0 non-null      float64
#  25  secondary_ssic_description         76 non-null     object
#  26  secondary_user_described_activity  76 non-null     object
#  27  registration_year                  76 non-null     int64
#  28  Address                            76 non-null     object
#  29  Add_lat                            76 non-null     float64
#  30  Add_lon                            76 non-null     float64
# dtypes: float64(3), int64(2), object(26)
# memory usage: 18.5+ KB

# %%
mm_1990s_nlive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1285 entries, 0 to 1284
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                1285 non-null   object
#  1   issuance_agency_id                 1285 non-null   object
#  2   entity_name                        1285 non-null   object
#  3   entity_type_description            1285 non-null   object
#  4   business_constitution_description  1285 non-null   object
#  5   company_type_description           1285 non-null   object
#  6   paf_constitution_description       1285 non-null   object
#  7   entity_status_description          1285 non-null   object
#  8   registration_incorporation_date    1285 non-null   object
#  9   uen_issue_date                     1285 non-null   object
#  10  address_type                       1285 non-null   object
#  11  block                              1285 non-null   object
#  12  street_name                        1285 non-null   object
#  13  level_no                           1285 non-null   object
#  14  unit_no                            1285 non-null   object
#  15  building_name                      1285 non-null   object
#  16  postal_code                        1285 non-null   object
#  17  other_address_line1                1285 non-null   object
#  18  other_address_line2                1285 non-null   object
#  19  account_due_date                   1285 non-null   object
#  20  annual_return_date                 1285 non-null   object
#  21  primary_ssic_code                  1285 non-null   int64
#  22  primary_ssic_description           1285 non-null   object
#  23  primary_user_described_activity    1285 non-null   object
#  24  secondary_ssic_code                0 non-null      float64
#  25  secondary_ssic_description         1285 non-null   object
#  26  secondary_user_described_activity  1285 non-null   object
#  27  registration_year                  1285 non-null   int64
#  28  Address                            1285 non-null   object
#  29  Add_lat                            1285 non-null   float64
#  30  Add_lon                            1285 non-null   float64
# dtypes: float64(3), int64(2), object(26)
# memory usage: 311.3+ KB

# %% [markdown]
# ###2000s

# %%
mm_2000s_live = get_live_shops(mm_2000s_geo)
mm_2000s_nlive = get_nlive_shops(mm_2000s_geo)

# %%
mm_2000s_live.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                118 non-null    object
#  1   issuance_agency_id                 118 non-null    object
#  2   entity_name                        118 non-null    object
#  3   entity_type_description            118 non-null    object
#  4   business_constitution_description  118 non-null    object
#  5   company_type_description           118 non-null    object
#  6   paf_constitution_description       118 non-null    object
#  7   entity_status_description          118 non-null    object
#  8   registration_incorporation_date    118 non-null    object
#  9   uen_issue_date                     118 non-null    object
#  10  address_type                       118 non-null    object
#  11  block                              118 non-null    object
#  12  street_name                        118 non-null    object
#  13  level_no                           118 non-null    object
#  14  unit_no                            118 non-null    object
#  15  building_name                      118 non-null    object
#  16  postal_code                        118 non-null    int64
#  17  other_address_line1                118 non-null    object
#  18  other_address_line2                118 non-null    object
#  19  account_due_date                   118 non-null    object
#  20  annual_return_date                 118 non-null    object
#  21  primary_ssic_code                  118 non-null    int64
#  22  primary_ssic_description           118 non-null    object
#  23  primary_user_described_activity    118 non-null    object
#  24  secondary_ssic_code                0 non-null      float64
#  25  secondary_ssic_description         118 non-null    object
#  26  secondary_user_described_activity  118 non-null    object
#  27  registration_year                  118 non-null    int64
#  28  Address                            118 non-null    object
#  29  Add_lat                            118 non-null    float64
#  30  Add_lon                            118 non-null    float64
# dtypes: float64(3), int64(3), object(25)
# memory usage: 28.7+ KB

# %%
mm_2000s_nlive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1381 entries, 0 to 1380
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                1381 non-null   object
#  1   issuance_agency_id                 1381 non-null   object
#  2   entity_name                        1381 non-null   object
#  3   entity_type_description            1381 non-null   object
#  4   business_constitution_description  1381 non-null   object
#  5   company_type_description           1381 non-null   object
#  6   paf_constitution_description       1381 non-null   object
#  7   entity_status_description          1381 non-null   object
#  8   registration_incorporation_date    1381 non-null   object
#  9   uen_issue_date                     1381 non-null   object
#  10  address_type                       1381 non-null   object
#  11  block                              1381 non-null   object
#  12  street_name                        1381 non-null   object
#  13  level_no                           1381 non-null   object
#  14  unit_no                            1381 non-null   object
#  15  building_name                      1380 non-null   object
#  16  postal_code                        1381 non-null   int64
#  17  other_address_line1                1381 non-null   object
#  18  other_address_line2                1381 non-null   object
#  19  account_due_date                   1381 non-null   object
#  20  annual_return_date                 1381 non-null   object
#  21  primary_ssic_code                  1381 non-null   int64
#  22  primary_ssic_description           1381 non-null   object
#  23  primary_user_described_activity    1381 non-null   object
#  24  secondary_ssic_code                0 non-null      float64
#  25  secondary_ssic_description         1381 non-null   object
#  26  secondary_user_described_activity  1381 non-null   object
#  27  registration_year                  1381 non-null   int64
#  28  Address                            1381 non-null   object
#  29  Add_lat                            1381 non-null   float64
#  30  Add_lon                            1381 non-null   float64
# dtypes: float64(3), int64(3), object(25)
# memory usage: 334.6+ KB

# %% [markdown]
# ###2010s

# %%
mm_2010s_live = get_live_shops(mm_2010s_geo)
mm_2010s_nlive = get_nlive_shops(mm_2010s_geo)

# %%
mm_2010s_live.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                166 non-null    object
#  1   issuance_agency_id                 166 non-null    object
#  2   entity_name                        166 non-null    object
#  3   entity_type_description            166 non-null    object
#  4   business_constitution_description  166 non-null    object
#  5   company_type_description           166 non-null    object
#  6   paf_constitution_description       166 non-null    object
#  7   entity_status_description          166 non-null    object
#  8   registration_incorporation_date    166 non-null    object
#  9   uen_issue_date                     166 non-null    object
#  10  address_type                       166 non-null    object
#  11  block                              166 non-null    object
#  12  street_name                        166 non-null    object
#  13  level_no                           166 non-null    object
#  14  unit_no                            166 non-null    object
#  15  building_name                      166 non-null    object
#  16  postal_code                        166 non-null    int64
#  17  other_address_line1                166 non-null    object
#  18  other_address_line2                166 non-null    object
#  19  account_due_date                   166 non-null    object
#  20  annual_return_date                 166 non-null    object
#  21  primary_ssic_code                  166 non-null    int64
#  22  primary_ssic_description           166 non-null    object
#  23  primary_user_described_activity    166 non-null    object
#  24  secondary_ssic_code                0 non-null      float64
#  25  secondary_ssic_description         166 non-null    object
#  26  secondary_user_described_activity  166 non-null    object
#  27  registration_year                  166 non-null    int64
#  28  Address                            166 non-null    object
#  29  Add_lat                            166 non-null    float64
#  30  Add_lon                            166 non-null    float64
# dtypes: float64(3), int64(3), object(25)
# memory usage: 40.3+ KB

# %%
mm_2010s_nlive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 845 entries, 0 to 844
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                845 non-null    object
#  1   issuance_agency_id                 845 non-null    object
#  2   entity_name                        844 non-null    object
#  3   entity_type_description            845 non-null    object
#  4   business_constitution_description  845 non-null    object
#  5   company_type_description           845 non-null    object
#  6   paf_constitution_description       845 non-null    object
#  7   entity_status_description          845 non-null    object
#  8   registration_incorporation_date    845 non-null    object
#  9   uen_issue_date                     845 non-null    object
#  10  address_type                       845 non-null    object
#  11  block                              845 non-null    object
#  12  street_name                        845 non-null    object
#  13  level_no                           845 non-null    object
#  14  unit_no                            845 non-null    object
#  15  building_name                      845 non-null    object
#  16  postal_code                        845 non-null    int64
#  17  other_address_line1                845 non-null    object
#  18  other_address_line2                845 non-null    object
#  19  account_due_date                   845 non-null    object
#  20  annual_return_date                 845 non-null    object
#  21  primary_ssic_code                  845 non-null    int64
#  22  primary_ssic_description           845 non-null    object
#  23  primary_user_described_activity    845 non-null    object
#  24  secondary_ssic_code                0 non-null      float64
#  25  secondary_ssic_description         845 non-null    object
#  26  secondary_user_described_activity  845 non-null    object
#  27  registration_year                  845 non-null    int64
#  28  Address                            845 non-null    object
#  29  Add_lat                            845 non-null    float64
#  30  Add_lon                            845 non-null    float64
# dtypes: float64(3), int64(3), object(25)
# memory usage: 204.8+ KB

# %% [markdown]
# ###2020s

# %%
mm_2020s_live = get_live_shops(mm_2020s_geo)
mm_2020s_nlive = get_nlive_shops(mm_2020s_geo)

# %%
mm_2020s_live.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                149 non-null    object
#  1   issuance_agency_id                 149 non-null    object
#  2   entity_name                        149 non-null    object
#  3   entity_type_description            149 non-null    object
#  4   business_constitution_description  149 non-null    object
#  5   company_type_description           149 non-null    object
#  6   paf_constitution_description       149 non-null    object
#  7   entity_status_description          149 non-null    object
#  8   registration_incorporation_date    149 non-null    object
#  9   uen_issue_date                     149 non-null    object
#  10  address_type                       149 non-null    object
#  11  block                              149 non-null    object
#  12  street_name                        149 non-null    object
#  13  level_no                           149 non-null    object
#  14  unit_no                            149 non-null    object
#  15  building_name                      149 non-null    object
#  16  postal_code                        149 non-null    int64
#  17  other_address_line1                149 non-null    object
#  18  other_address_line2                149 non-null    object
#  19  account_due_date                   149 non-null    object
#  20  annual_return_date                 149 non-null    object
#  21  primary_ssic_code                  149 non-null    int64
#  22  primary_ssic_description           149 non-null    object
#  23  primary_user_described_activity    149 non-null    object
#  24  secondary_ssic_code                0 non-null      float64
#  25  secondary_ssic_description         149 non-null    object
#  26  secondary_user_described_activity  149 non-null    object
#  27  registration_year                  149 non-null    int64
#  28  Address                            149 non-null    object
#  29  Add_lat                            149 non-null    float64
#  30  Add_lon                            149 non-null    float64
# dtypes: float64(3), int64(3), object(25)
# memory usage: 36.2+ KB

# %%
mm_2020s_nlive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                115 non-null    object
#  1   issuance_agency_id                 115 non-null    object
#  2   entity_name                        115 non-null    object
#  3   entity_type_description            115 non-null    object
#  4   business_constitution_description  115 non-null    object
#  5   company_type_description           115 non-null    object
#  6   paf_constitution_description       115 non-null    object
#  7   entity_status_description          115 non-null    object
#  8   registration_incorporation_date    115 non-null    object
#  9   uen_issue_date                     115 non-null    object
#  10  address_type                       115 non-null    object
#  11  block                              115 non-null    object
#  12  street_name                        115 non-null    object
#  13  level_no                           115 non-null    object
#  14  unit_no                            115 non-null    object
#  15  building_name                      115 non-null    object
#  16  postal_code                        115 non-null    int64
#  17  other_address_line1                115 non-null    object
#  18  other_address_line2                115 non-null    object
#  19  account_due_date                   115 non-null    object
#  20  annual_return_date                 115 non-null    object
#  21  primary_ssic_code                  115 non-null    int64
#  22  primary_ssic_description           115 non-null    object
#  23  primary_user_described_activity    115 non-null    object
#  24  secondary_ssic_code                0 non-null      float64
#  25  secondary_ssic_description         115 non-null    object
#  26  secondary_user_described_activity  115 non-null    object
#  27  registration_year                  115 non-null    int64
#  28  Address                            115 non-null    object
#  29  Add_lat                            115 non-null    float64
#  30  Add_lon                            115 non-null    float64
# dtypes: float64(3), int64(3), object(25)
# memory usage: 28.0+ KB

# %% [markdown]
# ###Save

# %%
#SAVE LIVE SHOPS
mm_1980s_live.to_csv('/content/drive/MyDrive/Mamak Stores/ACRA data/mamaks_1980s_live.csv', index=False)
mm_1990s_live.to_csv('/content/drive/MyDrive/Mamak Stores/ACRA data/mamaks_1990s_live.csv', index=False)
mm_2000s_live.to_csv('/content/drive/MyDrive/Mamak Stores/ACRA data/mamaks_2000s_live.csv', index=False)
mm_2010s_live.to_csv('/content/drive/MyDrive/Mamak Stores/ACRA data/mamaks_2010s_live.csv', index=False)
mm_2020s_live.to_csv('/content/drive/MyDrive/Mamak Stores/ACRA data/mamaks_2020s_live.csv', index=False)

# %%
#SAVE NON-LIVE SHOPS
mm_1980s_nlive.to_csv('/content/drive/MyDrive/Mamak Stores/ACRA data/mamaks_1980s_nlive.csv', index=False)
mm_1990s_nlive.to_csv('/content/drive/MyDrive/Mamak Stores/ACRA data/mamaks_1990s_nlive.csv', index=False)
mm_2000s_nlive.to_csv('/content/drive/MyDrive/Mamak Stores/ACRA data/mamaks_2000s_nlive.csv', index=False)
mm_2010s_nlive.to_csv('/content/drive/MyDrive/Mamak Stores/ACRA data/mamaks_2010s_nlive.csv', index=False)
mm_2020s_nlive.to_csv('/content/drive/MyDrive/Mamak Stores/ACRA data/mamaks_2020s_nlive.csv', index=False)
