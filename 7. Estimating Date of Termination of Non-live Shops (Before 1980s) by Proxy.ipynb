# %% [markdown]
# #The Modern Mamak: Estimating Date of Termination of Non-live Shops by Proxy
#
# Unfortunately, ACRA does not provide dates of termination of a registered business in Singapore. However, its registry does have records of other businesses and their addresses. In order to estimate the date of a shop's termination by proxy, the dataframe of non-live shops will be compared against the the dataframe of ACRA's entire registry to find any matching addresses. It is assumed that when a shop closes at one location, another often registers and takes over the rental space shortly after. Some issues that may arise could be:
#
# * A location may have remained vacant for several years before being taken over by another business *(inaccurate termination date)*
# * A location may have never been taken over by another business since then *(possible null value for termination date)*
# * A location may have been removed completely *(possible null value for termination date)*
# * A location may have been repurposed for non-business activities *(possible null value for termination date)*
#
# <br>
#
# Although this method is rather inaccurate, the project requires mostly broadstrokes analyses to proceed with the research. Additionally, other business directories online were scraped to determine some estimated termination dates. These directories, however, do not publish a business' termination date but rather the last update the directory has made to the status based on ACRA data. These directories are SGBusiness and RecordOwl. They will be compared to these estimated dates of termination and the earliest date would be the most likely date of termination.

# %% [markdown]
# # Libraries

# %%
#Google credentials
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import shapefile as shp

# %% [markdown]
# # Read Files

# %%
file_path = '/content/drive/MyDrive/Mamak Stores/ACRA data/all_acra_businesses.csv'
comb_df = pd.read_csv(file_path)
# Out:
# <ipython-input-3-b66bb05416f5>:2: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   comb_df = pd.read_csv(file_path)

# %%
path_b = "/content/drive/MyDrive/Mamak Stores/ACRA data/mamaks_b1980s_geo.csv"
mamaks_b1980s = pd.read_csv(path_b)

# %%
mamaks_b1980s['entity_status_description'].head(100)
# Out:
# 0                          na
# 1                          na
# 2                          na
# 3                          na
# 4                          na
#                ...
# 95                         na
# 96    Cancelled (Non-Renewal)
# 97                         na
# 98                         na
# 99                         na
# Name: entity_status_description, Length: 100, dtype: object

# %% [markdown]
# # Combine All Non-live Shops

# %%
mamaks_b1980s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2317 entries, 0 to 2316
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                2317 non-null   object
#  1   issuance_agency_id                 2317 non-null   object
#  2   entity_name                        2317 non-null   object
#  3   entity_type_description            2317 non-null   object
#  4   business_constitution_description  2317 non-null   object
#  5   company_type_description           2317 non-null   object
#  6   paf_constitution_description       2317 non-null   object
#  7   entity_status_description          2317 non-null   object
#  8   registration_incorporation_date    2317 non-null   object
#  9   uen_issue_date                     2317 non-null   object
#  10  address_type                       2317 non-null   object
#  11  block                              2317 non-null   object
#  12  street_name                        2317 non-null   object
#  13  level_no                           2317 non-null   object
#  14  unit_no                            2317 non-null   object
#  15  building_name                      2317 non-null   object
#  16  postal_code                        2317 non-null   object
#  17  other_address_line1                2317 non-null   object
#  18  other_address_line2                2317 non-null   object
#  19  account_due_date                   2317 non-null   object
#  20  annual_return_date                 2317 non-null   object
#  21  primary_ssic_code                  2317 non-null   int64
#  22  primary_ssic_description           2317 non-null   object
#  23  primary_user_described_activity    2317 non-null   object
#  24  secondary_ssic_code                0 non-null      float64
#  25  secondary_ssic_description         2317 non-null   object
#  26  secondary_user_described_activity  2317 non-null   object
#  27  registration_year                  2317 non-null   int64
#  28  Address                            2317 non-null   object
#  29  Add_lat                            2317 non-null   float64
#  30  Add_lon                            2317 non-null   float64
# dtypes: float64(3), int64(2), object(26)
# memory usage: 561.3+ KB

# %%
mamaks_b1980s.head()
# Out:
#          uen issuance_agency_id          entity_name entity_type_description  \
# 0  03056700M               ACRA    WING THYE HUP KEE                Business
# 1  03091500K               ACRA  WING HENG & COMPANY                Business
# 2  03143800L               ACRA        WIN & COMPANY                Business
# 3  03389400X               ACRA              WAN LEE                Business
# 4  03496500M               ACRA    W.S. RAM SINGH CO                Business
#
#   business_constitution_description company_type_description  \
# 0                   Sole Proprietor                       na
# 1                       Partnership                       na
# 2                   Sole Proprietor                       na
# 3                   Sole Proprietor                       na
# 4                   Sole Proprietor                       na
#
#   paf_constitution_description entity_status_description  \
# 0                           na                        na
# 1                           na                        na
# 2                           na                        na
# 3                           na                        na
# 4                           na                        na
#
#   registration_incorporation_date uen_issue_date  ... primary_ssic_code  \
# 0                      1974-12-09     2008-09-09  ...             47102
# 1                      1974-11-26     2008-09-09  ...             47102
# 2                      1974-12-07     2008-09-09  ...             47102
# 3                      1974-12-11     2008-09-09  ...             47102
# 4                      1974-12-28     2008-09-09  ...             47102
#
#                             primary_ssic_description  \
# 0  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 1  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 2  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 3  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 4  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
#
#   primary_user_described_activity secondary_ssic_code  \
# 0                              na                 NaN
# 1                              na                 NaN
# 2                              na                 NaN
# 3                              na                 NaN
# 4                              na                 NaN
#
#   secondary_ssic_description secondary_user_described_activity  \
# 0                         na                                na
# 1                         na                                na
# 2                         na                                na
# 3                         na                                na
# 4                         na                                na
#
#   registration_year                                          Address  \
# 0              1974                127 KALLANG ROAD SINGAPORE 208706
# 1              1974           272 SOUTH BRIDGE ROAD SINGAPORE 058821
# 2              1974  BLK 20 GHIM MOH ROAD STALL 157 SINGAPORE 270020
# 3              1974               128 ST. JOHN'S ROAD SINGAPORE 2775
# 4              1974              242 SERANGOON ROAD SINGAPORE 218087
#
#     Add_lat     Add_lon
# 0  1.308109  103.863335
# 1  1.281754  103.844879
# 2  1.311125  103.788211
# 3  1.456403  103.827852
# 4  1.309940  103.854199
#
# [5 rows x 31 columns]

# %%
cols_1 = ['block', 'street_name']
cols_2 = ['building_name']

#address_1 (block + street_name)
address_1 = (
    comb_df[cols_1]
    .fillna('')
    .astype(str)
    .replace('na', '')
    .agg(' '.join, axis=1)
    .str.strip()
)

#'#level_no-unit_no' (if both exist)
level_unit = comb_df[['level_no', 'unit_no']].fillna('').astype(str).replace('na', '')
address_2 = level_unit.apply(
    lambda x: f"#{x.level_no}-{x.unit_no}" if x.level_no and x.unit_no
    else f"#{x.unit_no}" if x.unit_no
    else '',
    axis=1
)

#combine with building_name
address_2 += ' ' + (
    comb_df[cols_2]
    .fillna('')
    .astype(str)
    .replace('na', '')
    .agg(' '.join, axis=1)
    .str.strip()
)

#add 'SINGAPORE' before postal code
address_3 = comb_df['postal_code'].fillna('').astype(str).replace('na', '').apply(
    lambda x: f"SINGAPORE {x}"
)

#full address
comb_df['Address'] = (
    address_1 + ' ' + address_2.str.strip() + ' ' + address_3
).str.replace(r'\s+', ' ', regex=True).str.strip()

# %% [markdown]
# #Find Businesses that Replaced Non-live Shops
#
# The entities listed in the dataframe of non-live shops are eliminated to avoid confusion with replaced shops. Then this dataframe of all other businesses will be checked for the same address to confirm that a mamak shop has been replaced. This dataset of replaced shops may contain the subsequent businesses that have also replaced those that initially replaced the mamak shops. Hence, the business with the registration date closest to that of the mamak shop will be used.

# %%
comb_df['entity_status_description'] = comb_df['entity_status_description'].astype(str)
comb_df_2 = comb_df.copy()
comb_df_2 = comb_df[~comb_df['entity_name'].isin(mamaks_b1980s['entity_name'])]

# %%
comb_df_2.head(3)
# Out:
#          uen issuance_agency_id       entity_name entity_type_description  \
# 0  00012700X               ACRA   WAH SEONG PRESS                Business
# 1  00021600C               ACRA      WONG YIN FOH                Business
# 2  00036800L               ACRA  WOON BROTHERS CO                Business
#
#   business_constitution_description company_type_description  \
# 0                   Sole Proprietor                       na
# 1                   Sole Proprietor                       na
# 2                       Partnership                       na
#
#   paf_constitution_description entity_status_description  \
# 0                           na       Ceased Registration
# 1                           na                 Cancelled
# 2                           na                        na
#
#   registration_incorporation_date uen_issue_date  ... name_of_audit_firm1  \
# 0                      1924-01-01     2008-09-09  ...                  na
# 1                      1974-09-19     2008-09-09  ...                  na
# 2                      1974-09-28     2008-09-09  ...                  na
#
#   uen_of_audit_firm2 name_of_audit_firm2 uen_of_audit_firm3  \
# 0                 na                  na                 na
# 1                 na                  na                 na
# 2                 na                  na                 na
#
#   name_of_audit_firm3 uen_of_audit_firm4 name_of_audit_firm4  \
# 0                  na                 na                  na
# 1                  na                 na                  na
# 2                  na                 na                  na
#
#   uen_of_audit_firm5 name_of_audit_firm5  \
# 0                 na                  na
# 1                 na                  na
# 2                 na                  na
#
#                                              Address
# 0                 5 KUNG CHONG ROAD SINGAPORE 159142
# 1                 259 VICTORIA STREET SINGAPORE 0718
# 2  101 KITCHENER ROAD #03-24 JALAN BESAR PLAZA SI...
#
# [3 rows x 54 columns]

# %%
replaced_shops = comb_df_2[comb_df_2['Address'].isin(mamaks_b1980s['Address'])]

# %%
replaced_shops.head()
# Out:
#            uen issuance_agency_id      entity_name entity_type_description  \
# 63   00854500J               ACRA          WAH KEE                Business
# 71   00949600M               ACRA         WAH KIEW                Business
# 79   01016000X               ACRA     WONG TAT KEE                Business
# 98   01632900K               ACRA         WAH HONG                Business
# 195  04240400B               ACRA  WINGS & COMPANY                Business
#
#     business_constitution_description company_type_description  \
# 63                    Sole Proprietor                       na
# 71                        Partnership                       na
# 79                    Sole Proprietor                       na
# 98                        Partnership                       na
# 195                   Sole Proprietor                       na
#
#     paf_constitution_description entity_status_description  \
# 63                            na                        na
# 71                            na                        na
# 79                            na                 Cancelled
# 98                            na                      Live
# 195                           na                 Cancelled
#
#     registration_incorporation_date uen_issue_date  ... name_of_audit_firm1  \
# 63                       1974-10-24     2008-09-09  ...                  na
# 71                       1974-12-04     2008-09-09  ...                  na
# 79                       1974-10-11     2008-09-09  ...                  na
# 98                       1974-10-16     2008-09-09  ...                  na
# 195                      1974-12-21     2008-09-09  ...                  na
#
#     uen_of_audit_firm2 name_of_audit_firm2 uen_of_audit_firm3  \
# 63                  na                  na                 na
# 71                  na                  na                 na
# 79                  na                  na                 na
# 98                  na                  na                 na
# 195                 na                  na                 na
#
#     name_of_audit_firm3 uen_of_audit_firm4 name_of_audit_firm4  \
# 63                   na                 na                  na
# 71                   na                 na                  na
# 79                   na                 na                  na
# 98                   na                 na                  na
# 195                  na                 na                  na
#
#     uen_of_audit_firm5 name_of_audit_firm5  \
# 63                  na                  na
# 71                  na                  na
# 79                  na                  na
# 98                  na                  na
# 195                 na                  na
#
#                                    Address
# 63       39 PURVIS STREET SINGAPORE 188616
# 71   460 RACE COURSE ROAD SINGAPORE 218700
# 79        52 SMITH STREET SINGAPORE 058959
# 98       586 GEYLANG ROAD SINGAPORE 389525
# 195       6 DE SOUZA STREET SINGAPORE 0104
#
# [5 rows x 54 columns]

# %%
# 1: Merge provision shops with all businesses that share the same address
merged = mamaks_b1980s.merge(
    comb_df,
    on='Address',
    how='left',
    suffixes=('_provision', '_nextshops')
)

# 2: Keep only businesses that opened AFTER the provision shop
merged = merged[merged['registration_incorporation_date_nextshops'] > merged['registration_incorporation_date_provision']]

# 3: Find the next closest registration date per address
next_business = merged.groupby('Address')['registration_incorporation_date_nextshops'].min().reset_index()

# 4: Merge back to `mm_all_nlive` to assign estimated `tdate_proxy`
mamaks_b1980s = mamaks_b1980s.merge(next_business, on='Address', how='left')
mamaks_b1980s.rename(columns={'registration_incorporation_date_nextshops': 'tdate_proxy'}, inplace=True)

mamaks_b1980s
# Out:
#             uen issuance_agency_id                    entity_name  \
# 0     03056700M               ACRA              WING THYE HUP KEE
# 1     03091500K               ACRA            WING HENG & COMPANY
# 2     03143800L               ACRA                  WIN & COMPANY
# 3     03389400X               ACRA                        WAN LEE
# 4     03496500M               ACRA              W.S. RAM SINGH CO
# ...         ...                ...                            ...
# 2312  21963600A               ACRA  ELLENBOROUGH STREET GUAN SOON
# 2313  22004600W               ACRA         ELLENBOROUGH NGEE HENG
# 2314  22106500L               ACRA       EUNOS CRESCENT MINI MART
# 2315  23622300C               ACRA       ENG CHOON PROVISION SHOP
# 2316  25092500A               ACRA      ENG SOON DEPARTMENT STORE
#
#      entity_type_description business_constitution_description  \
# 0                   Business                   Sole Proprietor
# 1                   Business                       Partnership
# 2                   Business                   Sole Proprietor
# 3                   Business                   Sole Proprietor
# 4                   Business                   Sole Proprietor
# ...                      ...                               ...
# 2312                Business                       Partnership
# 2313                Business                       Partnership
# 2314                Business                   Sole Proprietor
# 2315                Business                   Sole Proprietor
# 2316                Business                   Sole Proprietor
#
#      company_type_description paf_constitution_description  \
# 0                          na                           na
# 1                          na                           na
# 2                          na                           na
# 3                          na                           na
# 4                          na                           na
# ...                       ...                          ...
# 2312                       na                           na
# 2313                       na                           na
# 2314                       na                           na
# 2315                       na                           na
# 2316                       na                           na
#
#      entity_status_description registration_incorporation_date uen_issue_date  \
# 0                           na                      1974-12-09     2008-09-09
# 1                           na                      1974-11-26     2008-09-09
# 2                           na                      1974-12-07     2008-09-09
# 3                           na                      1974-12-11     2008-09-09
# 4                           na                      1974-12-28     2008-09-09
# ...                        ...                             ...            ...
# 2312                        na                      1976-07-30     2008-09-09
# 2313       Ceased Registration                      1976-08-13     2008-09-09
# 2314                        na                      1976-09-20     2008-09-09
# 2315                        na                      1978-02-21     2008-09-09
# 2316                        na                      1979-04-05     2008-09-09
#
#       ...                           primary_ssic_description  \
# 0     ...  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 1     ...  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 2     ...  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 3     ...  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 4     ...  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# ...   ...                                                ...
# 2312  ...  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 2313  ...  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 2314  ...  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 2315  ...  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 2316  ...  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
#
#      primary_user_described_activity secondary_ssic_code  \
# 0                                 na                 NaN
# 1                                 na                 NaN
# 2                                 na                 NaN
# 3                                 na                 NaN
# 4                                 na                 NaN
# ...                              ...                 ...
# 2312                              na                 NaN
# 2313                              na                 NaN
# 2314                              na                 NaN
# 2315                              na                 NaN
# 2316                              na                 NaN
#
#      secondary_ssic_description secondary_user_described_activity  \
# 0                            na                                na
# 1                            na                                na
# 2                            na                                na
# 3                            na                                na
# 4                            na                                na
# ...                         ...                               ...
# 2312                         na                                na
# 2313                         na                                na
# 2314                         na                                na
# 2315                         na                                na
# 2316                         na                                na
#
#      registration_year                                          Address  \
# 0                 1974                127 KALLANG ROAD SINGAPORE 208706
# 1                 1974           272 SOUTH BRIDGE ROAD SINGAPORE 058821
# 2                 1974  BLK 20 GHIM MOH ROAD STALL 157 SINGAPORE 270020
# 3                 1974               128 ST. JOHN'S ROAD SINGAPORE 2775
# 4                 1974              242 SERANGOON ROAD SINGAPORE 218087
# ...                ...                                              ...
# 2312              1976                       3 #03-131 SINGAPORE 050003
# 2313              1976   108 HOUGANG AVENUE 1 #01-1323 SINGAPORE 530108
# 2314              1976       6 EUNOS CRESCENT #01-2633 SINGAPORE 400006
# 2315              1978                 3V LORONG RENJONG SINGAPORE 1954
# 2316              1979                270 QUEEN STREET SINGAPORE 180270
#
#        Add_lat     Add_lon tdate_proxy
# 0     1.308109  103.863335  1990-04-06
# 1     1.281754  103.844879  1992-01-28
# 2     1.311125  103.788211         NaN
# 3     1.456403  103.827852         NaN
# 4     1.309940  103.854199  1975-04-04
# ...        ...         ...         ...
# 2312  1.352083  103.819836         NaN
# 2313  1.353421  103.890164  1982-11-24
# 2314  1.321170  103.904285  1997-12-29
# 2315  1.347137  103.860086         NaN
# 2316  1.300989  103.854099  1979-04-05
#
# [2317 rows x 32 columns]

# %%
next_business
# Out:
#                                                 Address  \
# 0                     1 BENCOOLEN STREET SINGAPORE 0718
# 1               1 COLOMBO COURT #06-03 SINGAPORE 179742
# 2              1 COLOMBO COURT #06-24B SINGAPORE 179742
# 3                           1 HORNE ROAD SINGAPORE 0820
# 4                       1 JALAN BERSEH SINGAPORE 209037
# ...                                                 ...
# 1214                 98A ST. JOHN'S ROAD SINGAPORE 2775
# 1215                   A WATERLOO STREET SINGAPORE 0718
# 1216             CARPENTER STREET #02-18 SINGAPORE 0105
# 1217  PRINCE EDWARD ROAD FINGER PIER BUILDING SINGAP...
# 1218                                          SINGAPORE
#
#      registration_incorporation_date_nextshops
# 0                                   1979-09-04
# 1                                   1979-12-05
# 2                                   1988-11-25
# 3                                   1977-01-22
# 4                                   1976-03-25
# ...                                        ...
# 1214                                1984-02-27
# 1215                                1982-12-07
# 1216                                1986-09-29
# 1217                                1987-05-13
# 1218                                1974-11-26
#
# [1219 rows x 2 columns]

# %%
termination_data_proxy = mamaks_b1980s[['entity_name', 'Address', 'tdate_proxy']]
termination_data_proxy.head()
# Out:
#            entity_name                                          Address  \
# 0    WING THYE HUP KEE                127 KALLANG ROAD SINGAPORE 208706
# 1  WING HENG & COMPANY           272 SOUTH BRIDGE ROAD SINGAPORE 058821
# 2        WIN & COMPANY  BLK 20 GHIM MOH ROAD STALL 157 SINGAPORE 270020
# 3              WAN LEE               128 ST. JOHN'S ROAD SINGAPORE 2775
# 4    W.S. RAM SINGH CO              242 SERANGOON ROAD SINGAPORE 218087
#
#   tdate_proxy
# 0  1990-04-06
# 1  1992-01-28
# 2         NaN
# 3         NaN
# 4  1975-04-04

# %%
termination_data_proxy['tdate_proxy'] = pd.to_datetime(
    termination_data_proxy['tdate_proxy'], errors='coerce')

termination_data_proxy['termination_year'] = termination_data_proxy['tdate_proxy'].dt.year
# Out:
# <ipython-input-25-c11112d92779>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   termination_data_proxy['tdate_proxy'] = pd.to_datetime(
# <ipython-input-25-c11112d92779>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   termination_data_proxy['termination_year'] = termination_data_proxy['tdate_proxy'].dt.year

# %%
termination_data_proxy.head()
# Out:
#            entity_name                                          Address  \
# 0    WING THYE HUP KEE                127 KALLANG ROAD SINGAPORE 208706
# 1  WING HENG & COMPANY           272 SOUTH BRIDGE ROAD SINGAPORE 058821
# 2        WIN & COMPANY  BLK 20 GHIM MOH ROAD STALL 157 SINGAPORE 270020
# 3              WAN LEE               128 ST. JOHN'S ROAD SINGAPORE 2775
# 4    W.S. RAM SINGH CO              242 SERANGOON ROAD SINGAPORE 218087
#
#   tdate_proxy  termination_year
# 0  1990-04-06            1990.0
# 1  1992-01-28            1992.0
# 2         NaT               NaN
# 3         NaT               NaN
# 4  1975-04-04            1975.0

# %%
#SAVE
termination_data_proxy.to_csv('/content/drive/MyDrive/Mamak Stores/shop_termination_data/termination_data_proxy_b.csv', index=False)

# %% [markdown]
# There are about 4516 terminated mamak shops since the 1980s. With this method, only about 2167 matching addresses were found from the rest of the ACRA database. This means over half of these locations were either never taken over, replaced by non-business activities or removed entirely. The next part of the analysis will consist of preparing data for URL webscraping and combining these estimated dates to compare and clean the data for further analysis.
