# %% [markdown]
# #The Modern Mamak: Exploring the New Socio-spatial Roles of Mamak Shops in Modern Singapore
#
# “Mamak” stalls, traditionally small provision shops established by Indian and Sri Lankan migrants, have long been essential fixtures in Singapore’s public housing estates. Historically, these stalls sold groceries and sundry items, serving the everyday needs in local communities. These stores also serve certain cultural demands for traditional spices and ingredients that often originate from India or China. The term "mamak" comes from the Tamil word "maa-ma," meaning “uncle”, as these were often honorifics used by children in Singapore to respectfully address adults in these stores. At their peak in the early 2000s, there were around 3,000 mamak stalls; however, due to increased competition from chain convenience stores, large supermarkets, and online shopping, the number has dwindled to just about a few hundred today.
#
# The decline of mamak stalls signified an economic and cultural shift. As housing developments experience intensive urban development and the advent of growing corporations, traditional mamak stalls are being outcompeted by larger, corporatized grocery chains and convenient stores that lack the unique character these shops once brought to public housing estates. Over the years, this change has made the experience of living in public housing less distinctive and more homogenised. Moreover, this shift risks outpricing lower income demographics of residents, catering primarily to residents with greater financial ability. This represents a form of spatial injustice within local communities. Additionally, these mamak stalls were also the primary income for small business owners, some of whom now try to adopt new roles as collection points for e-commerce delivery. Other mamak stores have since closed down as their traditional businesses models have become less viable.
#
# This project utilises a couple of data sources provided by Singapore's state-owned organisations. The shop dataset in this document is collected from the Accounting and Corporate Regulatory Authority of Singapore (ACRA) with the following as the definition of mamak shops:
#
# * Shops with Primary SSIC code 47102 (mini-marts, convenience stores and provision shops)
# * Shops without a Secondary SSIC (shops without secondary functions)
# * Shops that are 'Sole Proprietory' businesses
#
# <br>
#
# ###Contents:
# 1. Create New Dataframe of Only Relevant Columns
# 2. Filter By Primary SSIC Code 47102
# 3. Filter Out Shops with Secondary Functions
# 4. Filter Out non Sole-Proprietory Businesses
# 5. Data Cleaning and Sorting into Decades
# 6. Summary of Preliminary Analysis

# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Google credentials
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Read Files

# %%
file_path = '/content/drive/MyDrive/Mamak Stores/ACRA data/all_acra_businesses.csv'
comb_df = pd.read_csv(file_path)
# Out:
# <ipython-input-3-b66bb05416f5>:2: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   comb_df = pd.read_csv(file_path)

# %%
comb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1982005 entries, 0 to 1982004
# Data columns (total 53 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   uen                                object
#  1   issuance_agency_id                 object
#  2   entity_name                        object
#  3   entity_type_description            object
#  4   business_constitution_description  object
#  5   company_type_description           object
#  6   paf_constitution_description       object
#  7   entity_status_description          object
#  8   registration_incorporation_date    object
#  9   uen_issue_date                     object
#  10  address_type                       object
#  11  block                              object
#  12  street_name                        object
#  13  level_no                           object
#  14  unit_no                            object
#  15  building_name                      object
#  16  postal_code                        object
#  17  other_address_line1                object
#  18  other_address_line2                object
#  19  account_due_date                   object
#  20  annual_return_date                 object
#  21  primary_ssic_code                  int64
#  22  primary_ssic_description           object
#  23  primary_user_described_activity    object
#  24  secondary_ssic_code                object
#  25  secondary_ssic_description         object
#  26  secondary_user_described_activity  object
#  27  no_of_officers                     int64
#  28  former_entity_name1                object
#  29  former_entity_name2                object
#  30  former_entity_name3                object
#  31  former_entity_name4                object
#  32  former_entity_name5                object
#  33  former_entity_name6                object
#  34  former_entity_name7                object
#  35  former_entity_name8                object
#  36  former_entity_name9                object
#  37  former_entity_name10               object
#  38  former_entity_name11               object
#  39  former_entity_name12               object
#  40  former_entity_name13               object
#  41  former_entity_name14               object
#  42  former_entity_name15               object
#  43  uen_of_audit_firm1                 object
#  44  name_of_audit_firm1                object
#  45  uen_of_audit_firm2                 object
#  46  name_of_audit_firm2                object
#  47  uen_of_audit_firm3                 object
#  48  name_of_audit_firm3                object
#  49  uen_of_audit_firm4                 object
#  50  name_of_audit_firm4                object
#  51  uen_of_audit_firm5                 object
#  52  name_of_audit_firm5                object
# dtypes: int64(2), object(51)
# memory usage: 801.4+ MB

# %% [markdown]
# #1. New Dataframe of Only Relevant Columns
#
# Only columns 0 - 26 will be used and hence the rest will be filtered out for easier reading and comprehension. The other columns that are pertaining to audit details are not relevant to the project.

# %%
col_list = list(comb_df.columns[:27])
print(col_list)
# Out:
# ['uen', 'issuance_agency_id', 'entity_name', 'entity_type_description', 'business_constitution_description', 'company_type_description', 'paf_constitution_description', 'entity_status_description', 'registration_incorporation_date', 'uen_issue_date', 'address_type', 'block', 'street_name', 'level_no', 'unit_no', 'building_name', 'postal_code', 'other_address_line1', 'other_address_line2', 'account_due_date', 'annual_return_date', 'primary_ssic_code', 'primary_ssic_description', 'primary_user_described_activity', 'secondary_ssic_code', 'secondary_ssic_description', 'secondary_user_described_activity']

# %%
comb_df_2 = comb_df[col_list]

# %% [markdown]
# #2. Filter by Primary SSIC Code 47102
#
# The SSIC is the Singapore Standard of Industrial Classification used to categorise business entities in the country. 47102 refers to mini-marts, convenience stores and provision shops. Many traditional mamak shops were classified under this category dating from 1904 until today. However, this includes other larger chain stores as well. To combat this, other filters will be implemented to remove irrelevant entities from the dataset. Records before the 1980s from ACRA may also not be as reliable, hence the dataset of mamak shops will be constrained within the the timeframe from 1980 until now.

# %%
comb_df_2['primary_ssic_code'].astype(int)
# Out:
# 0          58110
# 1          24201
# 2          70102
# 3          56111
# 4          42909
#            ...
# 1982000    47213
# 1982001    66303
# 1982002    64202
# 1982003    64202
# 1982004    82303
# Name: primary_ssic_code, Length: 1982005, dtype: int64

# %%
mamaks_df = comb_df_2[comb_df_2['primary_ssic_code'] == 47102]
mamaks_df.reset_index(inplace = True, drop = True)
mamaks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14454 entries, 0 to 14453
# Data columns (total 27 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                14454 non-null  object
#  1   issuance_agency_id                 14454 non-null  object
#  2   entity_name                        14453 non-null  object
#  3   entity_type_description            14454 non-null  object
#  4   business_constitution_description  14454 non-null  object
#  5   company_type_description           14454 non-null  object
#  6   paf_constitution_description       14454 non-null  object
#  7   entity_status_description          14454 non-null  object
#  8   registration_incorporation_date    14454 non-null  object
#  9   uen_issue_date                     14454 non-null  object
#  10  address_type                       14454 non-null  object
#  11  block                              14454 non-null  object
#  12  street_name                        14454 non-null  object
#  13  level_no                           14454 non-null  object
#  14  unit_no                            14454 non-null  object
#  15  building_name                      14452 non-null  object
#  16  postal_code                        14454 non-null  object
#  17  other_address_line1                14454 non-null  object
#  18  other_address_line2                14454 non-null  object
#  19  account_due_date                   14454 non-null  object
#  20  annual_return_date                 14454 non-null  object
#  21  primary_ssic_code                  14454 non-null  int64
#  22  primary_ssic_description           14454 non-null  object
#  23  primary_user_described_activity    14454 non-null  object
#  24  secondary_ssic_code                14454 non-null  object
#  25  secondary_ssic_description         14454 non-null  object
#  26  secondary_user_described_activity  14454 non-null  object
# dtypes: int64(1), object(26)
# memory usage: 3.0+ MB

# %% [markdown]
# #3. Filter Out Shops with Secondary Functions
#
# Many provision shops also have secondary roles, such as pawn brokers and currency exchangers. These shops are less vulnerable to closure and do not fall within the traditional definitions of provision shops. Including these shops in the dataset may skew the results, therefore they will be filtered out.

# %%
mamaks_df['secondary_ssic_code'] = mamaks_df['secondary_ssic_code'].replace('na', np.nan)
# Out:
# <ipython-input-9-6583cbb1c83e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mamaks_df['secondary_ssic_code'] = mamaks_df['secondary_ssic_code'].replace('na', np.nan)

# %%
mamaks_filtered = mamaks_df[mamaks_df['secondary_ssic_code'].isnull()]

mamaks_filtered.reset_index(inplace = True, drop = True)
mamaks_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8060 entries, 0 to 8059
# Data columns (total 27 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                8060 non-null   object
#  1   issuance_agency_id                 8060 non-null   object
#  2   entity_name                        8059 non-null   object
#  3   entity_type_description            8060 non-null   object
#  4   business_constitution_description  8060 non-null   object
#  5   company_type_description           8060 non-null   object
#  6   paf_constitution_description       8060 non-null   object
#  7   entity_status_description          8060 non-null   object
#  8   registration_incorporation_date    8060 non-null   object
#  9   uen_issue_date                     8060 non-null   object
#  10  address_type                       8060 non-null   object
#  11  block                              8060 non-null   object
#  12  street_name                        8060 non-null   object
#  13  level_no                           8060 non-null   object
#  14  unit_no                            8060 non-null   object
#  15  building_name                      8059 non-null   object
#  16  postal_code                        8060 non-null   object
#  17  other_address_line1                8060 non-null   object
#  18  other_address_line2                8060 non-null   object
#  19  account_due_date                   8060 non-null   object
#  20  annual_return_date                 8060 non-null   object
#  21  primary_ssic_code                  8060 non-null   int64
#  22  primary_ssic_description           8060 non-null   object
#  23  primary_user_described_activity    8060 non-null   object
#  24  secondary_ssic_code                0 non-null      object
#  25  secondary_ssic_description         8060 non-null   object
#  26  secondary_user_described_activity  8060 non-null   object
# dtypes: int64(1), object(26)
# memory usage: 1.7+ MB

# %% [markdown]
# #4. Filter Out Shops that are not Sole Prioprietory or Partnership Businesses
#
# Most mamak shops are Sole Proprietorship businesses and not LLPs or Limited Liability Partnerships. The shopowner often run these stores by themselves or with the assistance of family members. They are also personally liable for all business debts and obligations, which puts them at a disadvantage compared to convenience store franchises and corporatised supermarkets.

# %%
mamaks_filtered = mamaks_filtered[
    mamaks_filtered['business_constitution_description'].isin(['Partnership', 'Sole Proprietor'])
].reset_index(drop=True)

mamaks_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7438 entries, 0 to 7437
# Data columns (total 27 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                7438 non-null   object
#  1   issuance_agency_id                 7438 non-null   object
#  2   entity_name                        7437 non-null   object
#  3   entity_type_description            7438 non-null   object
#  4   business_constitution_description  7438 non-null   object
#  5   company_type_description           7438 non-null   object
#  6   paf_constitution_description       7438 non-null   object
#  7   entity_status_description          7438 non-null   object
#  8   registration_incorporation_date    7438 non-null   object
#  9   uen_issue_date                     7438 non-null   object
#  10  address_type                       7438 non-null   object
#  11  block                              7438 non-null   object
#  12  street_name                        7438 non-null   object
#  13  level_no                           7438 non-null   object
#  14  unit_no                            7438 non-null   object
#  15  building_name                      7437 non-null   object
#  16  postal_code                        7438 non-null   object
#  17  other_address_line1                7438 non-null   object
#  18  other_address_line2                7438 non-null   object
#  19  account_due_date                   7438 non-null   object
#  20  annual_return_date                 7438 non-null   object
#  21  primary_ssic_code                  7438 non-null   int64
#  22  primary_ssic_description           7438 non-null   object
#  23  primary_user_described_activity    7438 non-null   object
#  24  secondary_ssic_code                0 non-null      object
#  25  secondary_ssic_description         7438 non-null   object
#  26  secondary_user_described_activity  7438 non-null   object
# dtypes: int64(1), object(26)
# memory usage: 1.5+ MB

# %%
mamaks_filtered.tail()
# Out:
#             uen issuance_agency_id               entity_name  \
# 7433  53437288X               ACRA  EMINENT 24-7 CONVENIENCE
# 7434  53437549M               ACRA               E-ZY CORNER
# 7435  53441172W               ACRA          ELPIS ENTERPRISE
# 7436  53472771M               ACRA                    ED@KAI
# 7437  53484972E               ACRA                  EVERMART
#
#      entity_type_description business_constitution_description  \
# 7433                Business                   Sole Proprietor
# 7434                Business                   Sole Proprietor
# 7435                Business                   Sole Proprietor
# 7436                Business                       Partnership
# 7437                Business                   Sole Proprietor
#
#      company_type_description paf_constitution_description  \
# 7433                       na                           na
# 7434                       na                           na
# 7435                       na                           na
# 7436                       na                           na
# 7437                       na                           na
#
#      entity_status_description registration_incorporation_date uen_issue_date  \
# 7433   Cancelled (Non-Renewal)                      2021-07-26     2021-07-26
# 7434   Cancelled (Non-Renewal)                      2021-07-31     2021-07-31
# 7435                      Live                      2021-10-16     2021-10-16
# 7436                      Live                      2023-08-28     2023-08-28
# 7437                      Live                      2024-05-02     2024-05-02
#
#       ... other_address_line1 other_address_line2 account_due_date  \
# 7433  ...                  na                  na               na
# 7434  ...                  na                  na               na
# 7435  ...                  na                  na               na
# 7436  ...                  na                  na               na
# 7437  ...                  na                  na               na
#
#      annual_return_date primary_ssic_code  \
# 7433                 na             47102
# 7434                 na             47102
# 7435                 na             47102
# 7436                 na             47102
# 7437                 na             47102
#
#                                primary_ssic_description  \
# 7433  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7434  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7435  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7436  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7437  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
#
#                        primary_user_described_activity secondary_ssic_code  \
# 7433             SALE OF DRINKS, SNACKS, GROCERY, ETC                  NaN
# 7434  MINI-MARTS,CONVENIENCE STORES AND PROVISION SHOP                 NaN
# 7435                                             47112                 NaN
# 7436                                             47102                 NaN
# 7437                                                na                 NaN
#
#      secondary_ssic_description  \
# 7433                         na
# 7434                         na
# 7435                         na
# 7436                         na
# 7437                         na
#
#                      secondary_user_described_activity
# 7433             SALE OF DRINKS, SNACKS, GROCERY, ETC
# 7434  MINI-MARTS,CONVENIENCE STORES AND PROVISION SHOP
# 7435                                             47112
# 7436                                             47102
# 7437                                                na
#
# [5 rows x 27 columns]

# %%
def remove_corp(df):
    corp_list = ['7-ELEVEN', 'CHEERS', 'ECON', 'FRANCHISEE', '7-11']
    pattern = '|'.join(corp_list)

    df = df[~df['entity_name'].str.contains(pattern, case=False, na=False)].copy()
    df = df[~df['primary_user_described_activity'].str.contains(pattern, case=False, na=False)].copy()

    return df

# %%
mamaks_filtered = remove_corp(mamaks_filtered)

# %%
mamaks_filtered['registration_incorporation_date'] = pd.to_datetime(
    mamaks_filtered['registration_incorporation_date'], errors='coerce')

mamaks_filtered['registration_year'] = mamaks_filtered['registration_incorporation_date'].dt.year

# %%
mamaks_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7392 entries, 0 to 7437
# Data columns (total 28 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                7392 non-null   object
#  1   issuance_agency_id                 7392 non-null   object
#  2   entity_name                        7391 non-null   object
#  3   entity_type_description            7392 non-null   object
#  4   business_constitution_description  7392 non-null   object
#  5   company_type_description           7392 non-null   object
#  6   paf_constitution_description       7392 non-null   object
#  7   entity_status_description          7392 non-null   object
#  8   registration_incorporation_date    7392 non-null   datetime64[ns]
#  9   uen_issue_date                     7392 non-null   object
#  10  address_type                       7392 non-null   object
#  11  block                              7392 non-null   object
#  12  street_name                        7392 non-null   object
#  13  level_no                           7392 non-null   object
#  14  unit_no                            7392 non-null   object
#  15  building_name                      7391 non-null   object
#  16  postal_code                        7392 non-null   object
#  17  other_address_line1                7392 non-null   object
#  18  other_address_line2                7392 non-null   object
#  19  account_due_date                   7392 non-null   object
#  20  annual_return_date                 7392 non-null   object
#  21  primary_ssic_code                  7392 non-null   int64
#  22  primary_ssic_description           7392 non-null   object
#  23  primary_user_described_activity    7392 non-null   object
#  24  secondary_ssic_code                0 non-null      object
#  25  secondary_ssic_description         7392 non-null   object
#  26  secondary_user_described_activity  7392 non-null   object
#  27  registration_year                  7392 non-null   int32
# dtypes: datetime64[ns](1), int32(1), int64(1), object(25)
# memory usage: 1.6+ MB

# %% [markdown]
# #5. Data Cleaning and Sorting into Decades

# %% [markdown]
# ### Combine Address Information into One Column ('Address')
#
# Following this data cleaning process, the addresses of these entities will be used for geocoding using Google API.

# %%
cols_1 = ['block', 'street_name']
cols_2 = ['building_name']

#address_1 (block + street_name)
address_1 = (
    mamaks_filtered[cols_1]
    .fillna('')
    .astype(str)
    .replace('na', '')
    .agg(' '.join, axis=1)
    .str.strip()
)

#'#level_no-unit_no' (if both exist)
level_unit = mamaks_filtered[['level_no', 'unit_no']].fillna('').astype(str).replace('na', '')
address_2 = level_unit.apply(
    lambda x: f"#{x.level_no}-{x.unit_no}" if x.level_no and x.unit_no
    else f"#{x.unit_no}" if x.unit_no
    else '',
    axis=1
)

#combine with building_name
address_2 += ' ' + (
    mamaks_filtered[cols_2]
    .fillna('')
    .astype(str)
    .replace('na', '')
    .agg(' '.join, axis=1)
    .str.strip()
)

#add 'SINGAPORE' before postal code
address_3 = mamaks_filtered['postal_code'].fillna('').astype(str).replace('na', '').apply(
    lambda x: f"SINGAPORE {x}"
)

#full address
mamaks_filtered['Address'] = (
    address_1 + ' ' + address_2.str.strip() + ' ' + address_3
).str.replace(r'\s+', ' ', regex=True).str.strip()

# %%
mamaks_filtered.tail(30)
# Out:
#             uen issuance_agency_id                   entity_name  \
# 7406  53146408C               ACRA                    EC-AC MARK
# 7407  53156223M               ACRA         EXPRESS MART @ MARINA
# 7408  53178268M               ACRA                EXPRESS AVENUE
# 7409  53188213J               ACRA                  ERP MINIMART
# 7410  53211441L               ACRA    EXPRESS MART @ CLARKE QUAY
# 7411  53211974J               ACRA             ECW TREASURE POTS
# 7412  53222955W               ACRA                       E-MART_
# 7413  53223118W               ACRA              ERVADI MINI MART
# 7414  53225747B               ACRA                         EJAAN
# 7415  53232138C               ACRA             EMMANUEL MINIMART
# 7416  53238583K               ACRA                E & P MINIMART
# 7417  53240851M               ACRA             ELSINO ENTERPRISE
# 7418  53292037J               ACRA                       EZBIZZZ
# 7419  53315023W               ACRA                   ELA TRADING
# 7420  53316025A               ACRA                    ESSIDHOUMI
# 7421  53335124C               ACRA          EVERGREEN TRADING CO
# 7422  53340297B               ACRA           EUHABITAT SUPERMART
# 7423  53341079K               ACRA                EXPRESS CORNER
# 7424  53345606A               ACRA                       E K JIN
# 7425  53349910X               ACRA             E2 PROVISION SHOP
# 7426  53354352E               ACRA                    EE VENDING
# 7427  53372032W               ACRA                E PUI MINIMART
# 7428  53386118K               ACRA  EMINENT 24-SEVEN CONVENIENCE
# 7430  53398829B               ACRA               EZYDEAL TRADING
# 7431  53401732X               ACRA                 ELITEZ BODEGA
# 7433  53437288X               ACRA      EMINENT 24-7 CONVENIENCE
# 7434  53437549M               ACRA                   E-ZY CORNER
# 7435  53441172W               ACRA              ELPIS ENTERPRISE
# 7436  53472771M               ACRA                        ED@KAI
# 7437  53484972E               ACRA                      EVERMART
#
#      entity_type_description business_constitution_description  \
# 7406                Business                   Sole Proprietor
# 7407                Business                   Sole Proprietor
# 7408                Business                       Partnership
# 7409                Business                   Sole Proprietor
# 7410                Business                   Sole Proprietor
# 7411                Business                   Sole Proprietor
# 7412                Business                   Sole Proprietor
# 7413                Business                   Sole Proprietor
# 7414                Business                   Sole Proprietor
# 7415                Business                   Sole Proprietor
# 7416                Business                   Sole Proprietor
# 7417                Business                   Sole Proprietor
# 7418                Business                   Sole Proprietor
# 7419                Business                   Sole Proprietor
# 7420                Business                   Sole Proprietor
# 7421                Business                   Sole Proprietor
# 7422                Business                   Sole Proprietor
# 7423                Business                       Partnership
# 7424                Business                   Sole Proprietor
# 7425                Business                   Sole Proprietor
# 7426                Business                   Sole Proprietor
# 7427                Business                   Sole Proprietor
# 7428                Business                   Sole Proprietor
# 7430                Business                   Sole Proprietor
# 7431                Business                   Sole Proprietor
# 7433                Business                   Sole Proprietor
# 7434                Business                   Sole Proprietor
# 7435                Business                   Sole Proprietor
# 7436                Business                       Partnership
# 7437                Business                   Sole Proprietor
#
#      company_type_description paf_constitution_description  \
# 7406                       na                           na
# 7407                       na                           na
# 7408                       na                           na
# 7409                       na                           na
# 7410                       na                           na
# 7411                       na                           na
# 7412                       na                           na
# 7413                       na                           na
# 7414                       na                           na
# 7415                       na                           na
# 7416                       na                           na
# 7417                       na                           na
# 7418                       na                           na
# 7419                       na                           na
# 7420                       na                           na
# 7421                       na                           na
# 7422                       na                           na
# 7423                       na                           na
# 7424                       na                           na
# 7425                       na                           na
# 7426                       na                           na
# 7427                       na                           na
# 7428                       na                           na
# 7430                       na                           na
# 7431                       na                           na
# 7433                       na                           na
# 7434                       na                           na
# 7435                       na                           na
# 7436                       na                           na
# 7437                       na                           na
#
#      entity_status_description registration_incorporation_date uen_issue_date  \
# 7406                      Live                      2009-07-03     2009-07-04
# 7407                 Cancelled                      2009-11-19     2009-11-20
# 7408                      Live                      2010-10-21     2010-10-22
# 7409   Cancelled (Non-Renewal)                      2011-03-26     2011-03-27
# 7410                 Cancelled                      2012-03-23     2012-03-24
# 7411                 Cancelled                      2012-03-30     2012-03-31
# 7412   Cancelled (Non-Renewal)                      2012-09-20     2012-09-21
# 7413                        na                      2012-09-22     2012-09-23
# 7414       Ceased Registration                      2012-11-05     2012-11-06
# 7415                      Live                      2013-03-03     2013-03-04
# 7416                 Cancelled                      2013-06-05     2013-06-06
# 7417       Ceased Registration                      2013-07-09     2013-07-10
# 7418                 Cancelled                      2015-03-16     2015-03-18
# 7419   Cancelled (Non-Renewal)                      2015-09-01     2015-09-02
# 7420       Ceased Registration                      2015-09-10     2015-09-11
# 7421                      Live                      2016-04-20     2016-04-20
# 7422   Cancelled (Non-Renewal)                      2016-06-26     2016-06-26
# 7423                      Live                      2016-07-06     2016-07-06
# 7424   Cancelled (Non-Renewal)                      2016-09-08     2016-09-08
# 7425       Ceased Registration                      2016-11-08     2016-11-08
# 7426   Cancelled (Non-Renewal)                      2017-01-14     2017-01-14
# 7427   Cancelled (Non-Renewal)                      2017-10-16     2017-10-16
# 7428                      Live                      2018-08-17     2018-08-17
# 7430   Cancelled (Non-Renewal)                      2019-06-06     2019-06-06
# 7431       Ceased Registration                      2019-08-11     2019-08-11
# 7433   Cancelled (Non-Renewal)                      2021-07-26     2021-07-26
# 7434   Cancelled (Non-Renewal)                      2021-07-31     2021-07-31
# 7435                      Live                      2021-10-16     2021-10-16
# 7436                      Live                      2023-08-28     2023-08-28
# 7437                      Live                      2024-05-02     2024-05-02
#
#       ... account_due_date annual_return_date primary_ssic_code  \
# 7406  ...               na                 na             47102
# 7407  ...               na                 na             47102
# 7408  ...               na                 na             47102
# 7409  ...               na                 na             47102
# 7410  ...               na                 na             47102
# 7411  ...               na                 na             47102
# 7412  ...               na                 na             47102
# 7413  ...               na                 na             47102
# 7414  ...               na                 na             47102
# 7415  ...               na                 na             47102
# 7416  ...               na                 na             47102
# 7417  ...               na                 na             47102
# 7418  ...               na                 na             47102
# 7419  ...               na                 na             47102
# 7420  ...               na                 na             47102
# 7421  ...               na                 na             47102
# 7422  ...               na                 na             47102
# 7423  ...               na                 na             47102
# 7424  ...               na                 na             47102
# 7425  ...               na                 na             47102
# 7426  ...               na                 na             47102
# 7427  ...               na                 na             47102
# 7428  ...               na                 na             47102
# 7430  ...               na                 na             47102
# 7431  ...               na                 na             47102
# 7433  ...               na                 na             47102
# 7434  ...               na                 na             47102
# 7435  ...               na                 na             47102
# 7436  ...               na                 na             47102
# 7437  ...               na                 na             47102
#
#                                primary_ssic_description  \
# 7406  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7407  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7408  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7409  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7410  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7411  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7412  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7413  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7414  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7415  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7416  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7417  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7418  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7419  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7420  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7421  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7422  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7423  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7424  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7425  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7426  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7427  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7428  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7430  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7431  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7433  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7434  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7435  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7436  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
# 7437  MINI-MARTS, CONVENIENCE STORES AND PROVISION S...
#
#                         primary_user_described_activity secondary_ssic_code  \
# 7406                                                 na                 NaN
# 7407                                                 na                 NaN
# 7408                                                 na                 NaN
# 7409                                  CONVENIENCE STORE                 NaN
# 7410                                          MINI-MART                 NaN
# 7411                                                 na                 NaN
# 7412            GENERAL GROCERY SUPPLIER FRUITS AND VEG                 NaN
# 7413                                                 na                 NaN
# 7414                                                 na                 NaN
# 7415                                                 na                 NaN
# 7416                                                 na                 NaN
# 7417                                            TRADING                 NaN
# 7418                                           MINIMART                 NaN
# 7419                                                 na                 NaN
# 7420                                              TRADE                 NaN
# 7421                                                 na                 NaN
# 7422                                                 na                 NaN
# 7423                                                 na                 NaN
# 7424                                                 na                 NaN
# 7425                                                 na                 NaN
# 7426  PUT VENDING MACHINE AT VARIOUS LOCATION DISPEN...                 NaN
# 7427                                                 na                 NaN
# 7428                                                 na                 NaN
# 7430                                                 na                 NaN
# 7431                                                 na                 NaN
# 7433              SALE OF DRINKS, SNACKS, GROCERY, ETC                  NaN
# 7434   MINI-MARTS,CONVENIENCE STORES AND PROVISION SHOP                 NaN
# 7435                                              47112                 NaN
# 7436                                              47102                 NaN
# 7437                                                 na                 NaN
#
#      secondary_ssic_description  \
# 7406                         na
# 7407                         na
# 7408                         na
# 7409                         na
# 7410                         na
# 7411                         na
# 7412                         na
# 7413                         na
# 7414                         na
# 7415                         na
# 7416                         na
# 7417                         na
# 7418                         na
# 7419                         na
# 7420                         na
# 7421                         na
# 7422                         na
# 7423                         na
# 7424                         na
# 7425                         na
# 7426                         na
# 7427                         na
# 7428                         na
# 7430                         na
# 7431                         na
# 7433                         na
# 7434                         na
# 7435                         na
# 7436                         na
# 7437                         na
#
#                       secondary_user_described_activity registration_year  \
# 7406                                                 na              2009
# 7407                                                 na              2009
# 7408                                                 na              2010
# 7409                                  CONVENIENCE STORE              2011
# 7410                                          MINI-MART              2012
# 7411                                                 na              2012
# 7412            GENERAL GROCERY SUPPLIER FRUITS AND VEG              2012
# 7413                                                 na              2012
# 7414                                                 na              2012
# 7415                                                 na              2013
# 7416                                                 na              2013
# 7417                                            TRADING              2013
# 7418                                           MINIMART              2015
# 7419                                                 na              2015
# 7420                                              TRADE              2015
# 7421                                                 na              2016
# 7422                                                 na              2016
# 7423                                                 na              2016
# 7424                                                 na              2016
# 7425                                                 na              2016
# 7426  PUT VENDING MACHINE AT VARIOUS LOCATION DISPEN...              2017
# 7427                                                 na              2017
# 7428                                                 na              2018
# 7430                                                 na              2019
# 7431                                                 na              2019
# 7433              SALE OF DRINKS, SNACKS, GROCERY, ETC               2021
# 7434   MINI-MARTS,CONVENIENCE STORES AND PROVISION SHOP              2021
# 7435                                              47112              2021
# 7436                                              47102              2023
# 7437                                                 na              2024
#
#                                                 Address
# 7406     25 AIRLINE ROAD AIRLINE HOUSE SINGAPORE 819829
# 7407  6 RAFFLES BOULEVARD #02-257 MARINA SQUARE SING...
# 7408  58 MARINE TERRACE #01-43 MARINE TERRACE HAVEN ...
# 7409         23B QUEEN'S CLOSE #01-183 SINGAPORE 141023
# 7410  1 ESPLANADE DRIVE #01-08A ESPLANADE - THEATRES...
# 7411   291D COMPASSVALE STREET #08-276 SINGAPORE 544291
# 7412             34 DOVER ROAD #01-143 SINGAPORE 130034
# 7413  54 CASHEW ROAD #02-03 CASHEW PARK SINGAPORE 67...
# 7414  258B PUNGGOL FIELD #6-07 PUNGGOL TOPAZ SINGAPO...
# 7415  819 TAMPINES STREET 81 #01-K1 TAMPINES POLYVIE...
# 7416   628 BEDOK RESERVOIR ROAD #01-K1 SINGAPORE 470628
# 7417             602 SENJA ROAD #01-15 SINGAPORE 670602
# 7418  262 JURONG EAST STREET 24 #01-489 SINGAPORE 60...
# 7419  432 JURONG WEST STREET 42 #02-566 SINGAPORE 64...
# 7420        667B PUNGGOL DRIVE #03-578 SINGAPORE 822667
# 7421  764 CHOA CHU KANG NORTH 5 #03-287 SINGAPORE 68...
# 7422  190 JALAN EUNOS #01-09 EUHABITAT SINGAPORE 419539
# 7423  1 KIM SENG PROMENADE #B2-K104 GREAT WORLD CITY...
# 7424  95 LORONG 4 TOA PAYOH #01-70 TOA PAYOH PALM SP...
# 7425  1 WOODLANDS INDUSTRIAL PARK E2 #01-01 NORDIX S...
# 7426  1 WEST COAST WALK #24-01 THE PARC CONDOMINIUM ...
# 7427  5001 BEACH ROAD #03-64G GOLDEN MILE COMPLEX SI...
# 7428  18A CANBERRA DRIVE #07-44 EIGHT COURTYARDS SIN...
# 7430  107 JALAN RAJAH #01-K1 RAJAH COURT SINGAPORE 3...
# 7431   127G JALAN DERMAWAN THE HILLOFT SINGAPORE 669112
# 7433  18A CANBERRA DRIVE #07-44 EIGHT COURTYARDS SIN...
# 7434  601C TAMPINES AVENUE 9 #10-838 TAMPINES GREENR...
# 7435  429B YISHUN AVENUE 11 #11-364 ORCHID SPRING @ ...
# 7436  710 CLEMENTI WEST STREET 2 #01-251 SINGAPORE 1...
# 7437    261B SENGKANG EAST WAY #07-408 SINGAPORE 542261
#
# [30 rows x 29 columns]

# %% [markdown]
# ### Get All Currently Live Provision Shops

# %%
mamaks_now_live = mamaks_filtered.copy()
mamaks_now_live = mamaks_now_live[
    (mamaks_now_live['entity_status_description'] == 'Live') |
    (mamaks_now_live['entity_status_description'] == 'Live Company')
]

mamaks_now_live.reset_index(inplace = True, drop = True)

mamaks_now_live.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 29 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   uen                                656 non-null    object
#  1   issuance_agency_id                 656 non-null    object
#  2   entity_name                        656 non-null    object
#  3   entity_type_description            656 non-null    object
#  4   business_constitution_description  656 non-null    object
#  5   company_type_description           656 non-null    object
#  6   paf_constitution_description       656 non-null    object
#  7   entity_status_description          656 non-null    object
#  8   registration_incorporation_date    656 non-null    datetime64[ns]
#  9   uen_issue_date                     656 non-null    object
#  10  address_type                       656 non-null    object
#  11  block                              656 non-null    object
#  12  street_name                        656 non-null    object
#  13  level_no                           656 non-null    object
#  14  unit_no                            656 non-null    object
#  15  building_name                      656 non-null    object
#  16  postal_code                        656 non-null    object
#  17  other_address_line1                656 non-null    object
#  18  other_address_line2                656 non-null    object
#  19  account_due_date                   656 non-null    object
#  20  annual_return_date                 656 non-null    object
#  21  primary_ssic_code                  656 non-null    int64
#  22  primary_ssic_description           656 non-null    object
#  23  primary_user_described_activity    656 non-null    object
#  24  secondary_ssic_code                0 non-null      object
#  25  secondary_ssic_description         656 non-null    object
#  26  secondary_user_described_activity  656 non-null    object
#  27  registration_year                  656 non-null    int32
#  28  Address                            656 non-null    object
# dtypes: datetime64[ns](1), int32(1), int64(1), object(26)
# memory usage: 146.2+ KB

# %%
#SAVE
mamaks_filtered.to_csv('/content/drive/MyDrive/Mamak Stores/ACRA data/mm_all.csv', index=False)
mamaks_now_live.to_csv('/content/drive/MyDrive/Mamak Stores/ACRA data/mm_2025_live.csv', index=False)
